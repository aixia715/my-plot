# %%
from my_plot import MyPlot
from data_csv import DataCsv

csv_obj = DataCsv(path='test_data/test.csv')
csv_obj2 = DataCsv(path='test_data/test2.csv')
plot = MyPlot()
plot.add_data(csv_obj.x, csv_obj.y, csv_obj.name)
plot.add_data(csv_obj2.x, csv_obj2.y, csv_obj2.name)
plot.set_plot_param(
    title='Test',
    xlabel='freq',
    ylabel='phase noise',
    grid=True,
    figsize=(12, 6)
)
plot.semilogx()
