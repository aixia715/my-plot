# %%
from plot_csv import PlotCSV
from data_csv import DataCsv

csv_obj = DataCsv(path='test_data/test.csv')
csv_obj2 = DataCsv(path='test_data/test2.csv')
plot = PlotCSV()
plot.add_data(csv_obj.x, csv_obj.y, '1')
plot.add_data(csv_obj2.x, csv_obj2.y, '2')
plot.set_plot_param(
    title='Test',
    xlabel='freq',
    ylabel='phase noise',
    grid=True,
    figsize=(12, 6)
)
plot.semilogx()
